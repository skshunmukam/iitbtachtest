# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df7=pd.read_excel('/content/GK-7-123.xlsx')

# %%
df7.head()
# Out:
#    S.No                 Name  Tamil-1  ...  Science-3  Social-3  TOTAL-3
# 0     1            ASHWIN .M       90  ...         87        99      427
# 1     2  DHATCHANAMOORTHY .M       57  ...         70        66      305
# 2     3            DINESH .E       82  ...         77        61      374
# 3     4      GNANASEKARAN .M       70  ...         76        78      318
# 4     5         IMMANUVEL .G       71  ...         80        89      408
#
# [5 rows x 20 columns]

# %%
df7.shape
# Out:
# (40, 20)

# %%
df7.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
df7.columns
# Out:
# Index(['S.No', 'Name', 'Tamil-1', 'English-1', 'Maths-1', 'Science-1',
#        'Social-1', 'TOTAL-1', 'Tamil-2', 'English-2', 'Maths-2', 'Science-2',
#        'Social-2', 'TOTAL-2', 'Tamil-3', 'English-3', 'Maths-3', 'Science-3',
#        'Social-3', 'TOTAL-3'],
#       dtype='object')

# %%
df7.describe()
# Out:
#             S.No    Tamil-1  English-1  ...  Science-3   Social-3    TOTAL-3
# count  40.000000  40.000000  40.000000  ...  40.000000  40.000000   40.00000
# mean   20.500000  67.225000  58.625000  ...  72.400000  73.800000  342.90000
# std    11.690452  16.207766  14.757332  ...  14.389811  15.847349   73.44623
# min     1.000000  25.000000  30.000000  ...  35.000000  36.000000  191.00000
# 25%    10.750000  56.500000  50.750000  ...  65.750000  64.000000  300.00000
# 50%    20.500000  71.000000  58.000000  ...  74.500000  73.000000  343.00000
# 75%    30.250000  76.250000  70.750000  ...  83.250000  85.250000  396.00000
# max    40.000000  95.000000  87.000000  ...  97.000000  99.000000  480.00000
#
# [8 rows x 19 columns]

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   S.No       40 non-null     int64
#  1   Name       40 non-null     object
#  2   Tamil-1    40 non-null     int64
#  3   English-1  40 non-null     int64
#  4   Maths-1    40 non-null     int64
#  5   Science-1  40 non-null     int64
#  6   Social-1   40 non-null     int64
#  7   TOTAL-1    40 non-null     int64
#  8   Tamil-2    40 non-null     int64
#  9   English-2  40 non-null     int64
#  10  Maths-2    40 non-null     int64
#  11  Science-2  40 non-null     int64
#  12  Social-2   40 non-null     int64
#  13  TOTAL-2    40 non-null     int64
#  14  Tamil-3    40 non-null     int64
#  15  English-3  40 non-null     int64
#  16  Maths-3    40 non-null     int64
#  17  Science-3  40 non-null     int64
#  18  Social-3   40 non-null     int64
#  19  TOTAL-3    40 non-null     int64
# dtypes: int64(19), object(1)
# memory usage: 6.4+ KB

# %%
df7.shape
# Out:
# (40, 20)

# %% [markdown]
# **Analysis of TOTAL-1,TOTAL-2,TOTAL-3**

# %%
Total1AVG=df7["TOTAL-1"].mean()
Total2AVG=df7["TOTAL-2"].mean()
Total3AVG=df7["TOTAL-3"].mean()

# %%
print(Total1AVG,Total2AVG,Total3AVG)
# Out:
# 309.8 333.375 342.9

# %%
T1=df7[df7["TOTAL-1"]>Total1AVG].shape[0]
T1
# Out:
# 20

# %%
T2=df7[df7["TOTAL-2"]>Total2AVG].shape[0]
T2
# Out:
# 20

# %%
T3=df7[df7["TOTAL-3"]>Total3AVG].shape[0]
T3
# Out:
# 20

# %% [markdown]
# **probablity of students scoring more than the mean of all totals**

# %%
Total_Students=df7.shape[0]
students_score_more_than_mean=df7[df7['TOTAL-1'] > df7['TOTAL-1'].mean()].shape[0]
probablity_of_students_score_more_than_mean=(students_score_more_than_mean/Total_Students)*100
print("Probability of Students Scoring more than average in TOTAL-1 :", probablity_of_students_score_more_than_mean)

Total_Students=df7.shape[0]
students_score_more_than_mean=df7[df7['TOTAL-2'] > df7['TOTAL-2'].mean()].shape[0]
probablity_of_students_score_more_than_mean=(students_score_more_than_mean/Total_Students)*100
print("Probability of Students Scoring more than average in TOTAL-2 :", probablity_of_students_score_more_than_mean)

Total_Students=df7.shape[0]
students_score_more_than_mean=df7[df7['TOTAL-3'] > df7['TOTAL-3'].mean()].shape[0]
probablity_of_students_score_more_than_mean=(students_score_more_than_mean/Total_Students)*100
print("Probability of Students Scoring more than average in TOTAL-3 :", probablity_of_students_score_more_than_mean)
# Out:
# Probability of Students Scoring more than average in TOTAL-1 : 50.0
# Probability of Students Scoring more than average in TOTAL-2 : 50.0
# Probability of Students Scoring more than average in TOTAL-3 : 50.0

# %% [markdown]
# **Probablity of student passing all the subject in Term-1**

# %%
Total_Students=df7.shape[0]
no_of_students_passing_in_all_subjects = df7[(df7['Tamil-1'] > 40) &(df7['English-1'] > 40) & (df7['Maths-1'] > 40) & (df7['Science-1'] > 40) & (df7['Social-1'] > 40)].shape[0]
probability_of_students_passing_in_all_the_subjects = (no_of_students_passing_in_all_subjects/Total_Students)*100
print("The Probability of Students Passing in all the Subjects in term1 is {0:.2f} %".format(probability_of_students_passing_in_all_the_subjects))
# Out:
# The Probability of Students Passing in all the Subjects in term1 is 65.00 %

# %% [markdown]
# **Probablity of student passing all the subjects in Term2**

# %%
Total_Students=df7.shape[0]
no_of_students_passing_in_all_subjects = df7[(df7['Tamil-2'] > 40) &(df7['English-2'] > 40) & (df7['Maths-2'] > 40) & (df7['Science-2'] > 40) & (df7['Social-2'] > 40)].shape[0]
probability_of_students_passing_in_all_the_subjects = (no_of_students_passing_in_all_subjects/Total_Students)*100
print("The Probability of Students Passing in all the Subjects in term2 is {0:.2f} %".format(probability_of_students_passing_in_all_the_subjects))
# Out:
# The Probability of Students Passing in all the Subjects in term2 is 90.00 %

# %% [markdown]
# **Probablity of student passing all the subjects in term3**

# %%
Total_Students=df7.shape[0]
no_of_students_passing_in_all_subjects = df7[(df7['Tamil-3'] > 40) &(df7['English-3'] > 40) & (df7['Maths-3'] > 40) & (df7['Science-3'] > 40) & (df7['Social-3'] > 40)].shape[0]
probability_of_students_passing_in_all_the_subjects = (no_of_students_passing_in_all_subjects/Total_Students)*100
print("The Probability of Students Passing in all the Subjects in term3 is {0:.2f} %".format(probability_of_students_passing_in_all_the_subjects))
# Out:
# The Probability of Students Passing in all the Subjects in term3 is 90.00 %

# %%
df7.boxplot(column=['TOTAL-1'])

# %%
df7.boxplot(column=['TOTAL-2'])

# %%
df7.boxplot(column=['TOTAL-3'])

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(df7['TOTAL-1'], palette = 'dark')
plt.title('TOTAL-1',fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(df7['TOTAL-2'], palette = 'dark')
plt.title('TOTAL-2',fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(df7['TOTAL-3'], palette = 'dark')
plt.title('TOTAL-3',fontsize = 20)
plt.show()

# %%
df7.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e182d1590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e177d8190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e18330790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e18405d90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e183ca3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e1837f9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e183aab10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e1777a5d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e1777a610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e177afd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e1772b850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e176e2e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e1769be90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e176603d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e176168d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e175cddd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e17590310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e17546810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e174fcd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e174bf250>]],
#       dtype=object)

# %%
plt.hist(df7['TOTAL-1'], bins = 14)
plt.xlabel('TOTAL-1')
plt.ylabel('Count')
plt.title('Distribution of TOTAL-1')
# Out:
# Text(0.5, 1.0, 'Distribution of TOTAL-1')

# %%
plt.hist(df7['TOTAL-2'], bins = 14)
plt.xlabel('TOTAL-2')
plt.ylabel('Count')
plt.title('Distribution of TOTAL-2')
# Out:
# Text(0.5, 1.0, 'Distribution of TOTAL-2')

# %%
plt.hist(df7['TOTAL-3'], bins = 14)
plt.xlabel('TOTAL-3')
plt.ylabel('Count')
plt.title('Distribution of TOTAL-3')
# Out:
# Text(0.5, 1.0, 'Distribution of TOTAL-3')

# %%
plt.figure(figsize=(20,20))
correlation_matrix = df7.corr()
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
plt.show()

# %%
sns.displot(df7['TOTAL-1'])

# %%
sns.displot(df7['TOTAL-2'])

# %%
sns.displot(df7['TOTAL-3'])

# %% [markdown]
# **ANALYSIS OF EACH SUBJECT IN TERM-1**

# %% [markdown]
# **Probablity of students scoring more than 50 in Tamil-1**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['Tamil-1']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Tamil-1 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Tamil-1 : 82.5

# %%
df7.boxplot(column=['Tamil-1'])

# %% [markdown]
# **Probablity of students scoring more than 50 in English-1**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['English-1']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in English-1 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in English-1 : 75.0

# %%
df7.boxplot(column=['English-1'])

# %% [markdown]
# **Probablity of students scoring more than 50 in Maths-1**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['Maths-1']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Maths-1 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Maths-1 : 55.00000000000001

# %%
df7.boxplot(column=['Maths-1'])

# %% [markdown]
# **Probablity of students scoring more than 50 in Science-1**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['Science-1']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Science-1 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Science-1 : 72.5

# %%
df7.boxplot(column=['Science-1'])

# %% [markdown]
# **Probablity of students scoring more than 50 in Social-1**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['Social-1']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Social-1 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Social-1 : 92.5

# %%
df7.boxplot(column=['Social-1'])

# %% [markdown]
# **Analysis of each subject in term2**

# %% [markdown]
# **Probablity of students scoring more than 50 in Tamil-2**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['Tamil-2']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Tamil-2 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Tamil-2 : 85.0

# %%
df7.boxplot(column=['Tamil-2'])

# %% [markdown]
# **Probablity of students scoring more than 50 in English-2**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['English-2']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in English-2 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in English-2 : 80.0

# %%
df7.boxplot(column=['English-2'])

# %% [markdown]
# **Probablity of student scoring more than 50 in Maths-2**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['Maths-2']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Maths-2 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Maths-2 : 72.5

# %%
df7.boxplot(column=['Maths-2'])

# %% [markdown]
# **Probablity of student scoring more than 50 in Science-2**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['Science-2']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Science-2 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Science-2 : 75.0

# %%
df7.boxplot(column=['Science-2'])

# %% [markdown]
# **Probablity of student scoring more than 50 in Social-2**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['Social-2']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Social-2 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Social-2 : 92.5

# %%
df7.boxplot(column=['Social-2'])

# %% [markdown]
# **Analysis of each subject in term3**

# %% [markdown]
# **Probablity of students scoring more than 50 in Tamil-3**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['Tamil-3']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Tamil-3 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Tamil-3 : 85.0

# %%
df7.boxplot(column=['Tamil-3'])

# %% [markdown]
# **Probablity of students scoring more than 50 in English-3**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['English-3']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in English-3 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in English-3 : 72.5

# %%
df7.boxplot(column=['English-3'])

# %% [markdown]
# **Probablity of students scoring more than 50 in Maths-3**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['Maths-3']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Maths-3 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Maths-3 : 72.5

# %%
df7.boxplot(column=['Maths-3'])

# %% [markdown]
# **Probablity of students scoring more than 50 in Science-3**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['Science-3']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Science-3 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Science-3 : 95.0

# %%
df7.boxplot(column=['Science-3'])

# %% [markdown]
# **Probablity of students scoring more than 50 in Social-3**

# %%
total_students = df7.shape[0]
students_score_more_than_50 = df7[df7['Social-3']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Social-3 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Social-3 : 92.5

# %%
df7.boxplot(column=['Social-3'])
