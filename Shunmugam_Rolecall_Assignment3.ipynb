# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df8=pd.read_excel('/content/GK-8-123.xlsx')

# %%
df8.head()
# Out:
#    S.No                 Name  Tamil-1  ...  Science-3  Social-3  TOTAL-3
# 0     1            ASHWIN .M       91  ...         88        87      448
# 1     2  DHATCHANAMOORTHY .M       56  ...         41        58      256
# 2     3            DINESH .E       82  ...         75        73      386
# 3     4      GNANASEKARAN .M       64  ...         56        65      289
# 4     5         IMMANUVEL .G       78  ...         63        68      344
#
# [5 rows x 20 columns]

# %%
df8.shape
# Out:
# (40, 20)

# %%
df8.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
df8.columns
# Out:
# Index(['S.No', 'Name', 'Tamil-1', 'English-1', 'Maths-1', 'Science-1',
#        'Social-1', 'TOTAL-1', 'Tamil-2', 'English-2', 'Maths-2', 'Science-2',
#        'Social-2', 'TOTAL-2', 'Tamil-3', 'English-3', 'Maths-3', 'Science-3',
#        'Social-3', 'TOTAL-3'],
#       dtype='object')

# %%
df8.describe()
# Out:
#             S.No    Tamil-1  English-1  ...  Science-3   Social-3     TOTAL-3
# count  40.000000  40.000000  40.000000  ...  40.000000  40.000000   40.000000
# mean   20.500000  71.150000  53.825000  ...  63.900000  65.525000  329.775000
# std    11.690452  17.574092  12.114597  ...  17.020049  14.239684   67.801932
# min     1.000000  26.000000  33.000000  ...  29.000000  30.000000  176.000000
# 25%    10.750000  61.500000  45.500000  ...  51.000000  57.500000  287.750000
# 50%    20.500000  76.500000  51.500000  ...  62.500000  65.000000  334.500000
# 75%    30.250000  84.250000  62.250000  ...  76.500000  73.000000  373.750000
# max    40.000000  96.000000  81.000000  ...  94.000000  95.000000  463.000000
#
# [8 rows x 19 columns]

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   S.No       40 non-null     int64
#  1   Name       40 non-null     object
#  2   Tamil-1    40 non-null     int64
#  3   English-1  40 non-null     int64
#  4   Maths-1    40 non-null     int64
#  5   Science-1  40 non-null     int64
#  6   Social-1   40 non-null     int64
#  7   TOTAL-1    40 non-null     int64
#  8   Tamil-2    40 non-null     int64
#  9   English-2  40 non-null     int64
#  10  Maths-2    40 non-null     int64
#  11  Science-2  40 non-null     int64
#  12  Social-2   40 non-null     int64
#  13  TOTAL-2    40 non-null     int64
#  14  Tamil-3    40 non-null     int64
#  15  English-3  40 non-null     int64
#  16  Maths-3    40 non-null     int64
#  17  Science-3  40 non-null     int64
#  18  Social-3   40 non-null     int64
#  19  TOTAL-3    40 non-null     int64
# ...

# %%
df8.shape
# Out:
# (40, 20)

# %% [markdown]
# **Analysis of TOTAL-1,TOTAL-2,TOTAL-3**

# %%
Total1AVG=df8["TOTAL-1"].mean()
Total2AVG=df8["TOTAL-2"].mean()
Total3AVG=df8["TOTAL-3"].mean()

# %%
print(Total1AVG,Total2AVG,Total3AVG)
# Out:
# 319.05 325.25 329.775

# %%
T1=df8[df8["TOTAL-1"]>Total1AVG].shape[0]
T1
# Out:
# 18

# %%
T2=df8[df8["TOTAL-2"]>Total2AVG].shape[0]
T2
# Out:
# 19

# %%
T3=df8[df8["TOTAL-3"]>Total3AVG].shape[0]
T3
# Out:
# 20

# %% [markdown]
# **probablity of students scoring more than the mean of all totals**

# %%
Total_Students=df8.shape[0]
students_score_more_than_mean=df8[df8['TOTAL-1'] > df8['TOTAL-1'].mean()].shape[0]
probablity_of_students_score_more_than_mean=(students_score_more_than_mean/Total_Students)*100
print("Probability of Students Scoring more than average in TOTAL-1 :", probablity_of_students_score_more_than_mean)

Total_Students=df8.shape[0]
students_score_more_than_mean=df8[df8['TOTAL-2'] > df8['TOTAL-2'].mean()].shape[0]
probablity_of_students_score_more_than_mean=(students_score_more_than_mean/Total_Students)*100
print("Probability of Students Scoring more than average in TOTAL-2 :", probablity_of_students_score_more_than_mean)

Total_Students=df8.shape[0]
students_score_more_than_mean=df8[df8['TOTAL-3'] > df8['TOTAL-3'].mean()].shape[0]
probablity_of_students_score_more_than_mean=(students_score_more_than_mean/Total_Students)*100
print("Probability of Students Scoring more than average in TOTAL-3 :", probablity_of_students_score_more_than_mean)
# Out:
# Probability of Students Scoring more than average in TOTAL-1 : 45.0
# Probability of Students Scoring more than average in TOTAL-2 : 47.5
# Probability of Students Scoring more than average in TOTAL-3 : 50.0

# %% [markdown]
# **Probablity of student passing all the subject in Term-1**

# %%
Total_Students=df8.shape[0]
no_of_students_passing_in_all_subjects = df8[(df8['Tamil-1'] > 40) &(df8['English-1'] > 40) & (df8['Maths-1'] > 40) & (df8['Science-1'] > 40) & (df8['Social-1'] > 40)].shape[0]
probability_of_students_passing_in_all_the_subjects = (no_of_students_passing_in_all_subjects/Total_Students)*100
print("The Probability of Students Passing in all the Subjects in term1 is {0:.2f} %".format(probability_of_students_passing_in_all_the_subjects))
# Out:
# The Probability of Students Passing in all the Subjects in term1 is 82.50 %

# %% [markdown]
# **Probablity of student passing all the subjects in Term2**

# %%
Total_Students=df8.shape[0]
no_of_students_passing_in_all_subjects = df8[(df8['Tamil-2'] > 40) &(df8['English-2'] > 40) & (df8['Maths-2'] > 40) & (df8['Science-2'] > 40) & (df8['Social-2'] > 40)].shape[0]
probability_of_students_passing_in_all_the_subjects = (no_of_students_passing_in_all_subjects/Total_Students)*100
print("The Probability of Students Passing in all the Subjects in term2 is {0:.2f} %".format(probability_of_students_passing_in_all_the_subjects))
# Out:
# The Probability of Students Passing in all the Subjects in term2 is 87.50 %

# %% [markdown]
# **Probablity of student passing all the subjects in term3**

# %%
Total_Students=df8.shape[0]
no_of_students_passing_in_all_subjects = df8[(df8['Tamil-3'] > 40) &(df8['English-3'] > 40) & (df8['Maths-3'] > 40) & (df8['Science-3'] > 40) & (df8['Social-3'] > 40)].shape[0]
probability_of_students_passing_in_all_the_subjects = (no_of_students_passing_in_all_subjects/Total_Students)*100
print("The Probability of Students Passing in all the Subjects in term3 is {0:.2f} %".format(probability_of_students_passing_in_all_the_subjects))
# Out:
# The Probability of Students Passing in all the Subjects in term3 is 92.50 %

# %%
df8.boxplot(column=['TOTAL-1'])

# %%
df8.boxplot(column=['TOTAL-2'])

# %%
df8.boxplot(column=['TOTAL-3'])

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(df8['TOTAL-1'], palette = 'dark')
plt.title('TOTAL-1',fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(df8['TOTAL-2'], palette = 'dark')
plt.title('TOTAL-2',fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(df8['TOTAL-3'], palette = 'dark')
plt.title('TOTAL-3',fontsize = 20)
plt.show()

# %%
df8.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e18f354d0>,
# ...
#       dtype=object)

# %%
plt.hist(df8['TOTAL-1'], bins = 14)
plt.xlabel('TOTAL-1')
plt.ylabel('Count')
plt.title('Distribution of TOTAL-1')
# Out:
# Text(0.5, 1.0, 'Distribution of TOTAL-1')

# %%
plt.hist(df8['TOTAL-2'], bins = 14)
plt.xlabel('TOTAL-2')
plt.ylabel('Count')
plt.title('Distribution of TOTAL-2')
# Out:
# Text(0.5, 1.0, 'Distribution of TOTAL-2')

# %%
plt.hist(df8['TOTAL-3'], bins = 14)
plt.xlabel('TOTAL-3')
plt.ylabel('Count')
plt.title('Distribution of TOTAL-3')
# Out:
# Text(0.5, 1.0, 'Distribution of TOTAL-3')

# %%
plt.figure(figsize=(20,20))
correlation_matrix = df8.corr()
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
plt.show()

# %%
sns.displot(df8['TOTAL-1'])

# %%
sns.displot(df8['TOTAL-2'])

# %%
sns.displot(df8['TOTAL-3'])

# %% [markdown]
# **ANALYSIS OF EACH SUBJECT IN TERM-1**

# %% [markdown]
# **Probablity of students scoring more than 50 in Tamil-1**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['Tamil-1']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Tamil-1 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Tamil-1 : 87.5

# %%
df8.boxplot(column=['Tamil-1'])

# %% [markdown]
# **Probablity of students scoring more than 50 in English-1**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['English-1']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in English-1 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in English-1 : 52.5

# %%
df8.boxplot(column=['English-1'])

# %% [markdown]
# **Probablity of students scoring more than 50 in Maths-1**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['Maths-1']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Maths-1 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Maths-1 : 90.0

# %%
df8.boxplot(column=['Maths-1'])

# %% [markdown]
# **Probablity of students scoring more than 50 in Science-1**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['Science-1']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Science-1 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Science-1 : 52.5

# %%
df8.boxplot(column=['Science-1'])

# %% [markdown]
# **Probablity of students scoring more than 50 in Social-1**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['Social-1']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Social-1 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Social-1 : 95.0

# %%
df8.boxplot(column=['Social-1'])

# %% [markdown]
# **Analysis of each subject in term2**

# %% [markdown]
# **Probablity of students scoring more than 50 in Tamil-2**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['Tamil-2']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Tamil-2 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Tamil-2 : 90.0

# %%
df8.boxplot(column=['Tamil-2'])

# %% [markdown]
# **Probablity of students scoring more than 50 in English-2**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['English-2']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in English-2 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in English-2 : 62.5

# %%
df8.boxplot(column=['English-2'])

# %% [markdown]
# **Probablity of student scoring more than 50 in Maths-2**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['Maths-2']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Maths-2 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Maths-2 : 80.0

# %%
df8.boxplot(column=['Maths-2'])

# %% [markdown]
# **Probablity of student scoring more than 50 in Science-2**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['Science-2']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Science-2 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Science-2 : 62.5

# %%
df8.boxplot(column=['Science-2'])

# %% [markdown]
# **Probablity of student scoring more than 50 in Social-2**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['Social-2']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Social-2 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Social-2 : 92.5

# %%
df8.boxplot(column=['Social-2'])

# %% [markdown]
# **Analysis of each subject in term3**

# %% [markdown]
# **Probablity of students scoring more than 50 in Tamil-3**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['Tamil-3']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Tamil-3 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Tamil-3 : 95.0

# %%
df8.boxplot(column=['Tamil-3'])

# %% [markdown]
# **Probablity of students scoring more than 50 in English-3**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['English-3']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in English-3 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in English-3 : 77.5

# %%
df8.boxplot(column=['English-3'])

# %% [markdown]
# **Probablity of students scoring more than 50 in Maths-3**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['Maths-3']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Maths-3 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Maths-3 : 85.0

# %%
df8.boxplot(column=['Maths-3'])

# %% [markdown]
# **Probablity of students scoring more than 50 in Science-3**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['Science-3']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Science-3 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Science-3 : 77.5

# %%
df8.boxplot(column=['Science-3'])

# %% [markdown]
# **Probablity of students scoring more than 50 in Social-3**

# %%
total_students = df8.shape[0]
students_score_more_than_50 = df8[df8['Social-3']>50].shape[0]
probability_of_students_scoring_more_than_50 = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Social-3 :", probability_of_students_scoring_more_than_50)
# Out:
# Probability of Students Scoring more than 50 marks in Social-3 : 87.5

# %%
df8.boxplot(column=['Social-3'])
